# %% [markdown]
# # Chebyshev bias explorer
#
# Give an **LMFDB elliptic-curve label** and get its Chebyshev-bias graph.
#
# S(x) = sum_{p<=x} a_p/p  ~  (1/2 - rank) * loglog x + c   (Aoki-Koyama bias).
#
# The red dashed line is the Aoki-Koyama theory slope `1/2 - (analytic rank)`.
#
# Edit the label in the next cell and run (Shift+Enter).

# %%
# %matplotlib inline
from bias_explorer import plot_bias

# Try: 11.a1 (rank 0), 37.a1 (rank 1), 389.a1 (rank 2), 5077.a1 (rank 3)
ax, rank = plot_bias("389.a1")
